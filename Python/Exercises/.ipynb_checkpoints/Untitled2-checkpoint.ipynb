# %%
# toggle the output section and using line numbers
x = [1,2,3,4]
x
# Out:
# [1, 2, 3, 4]

# %%
x = [1,2,3,4]
x
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# This is a markdown cell.

# %%
x = [1,2,3,4]
x
# Out:
# [1, 2, 3, 4]

# %%
x = 5 + 3
print(x)
# Out:
# 8

# %% [markdown]
# NameError described below.

# %%
print(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-d9183e048de3> in <module>
# ----> 1 print(y)
#
# NameError: name 'y' is not defined

# %%
prit(y)

# %%
print(x)

# %%
print(x-1)

# %%
num = 8
converted_num = str(num)
print(converted_num)
type(converted_num)

# %%
list1=[1,2,3,4,5]
str1 = "6"
for i in list1:
    str1=str1+str(i)
    
print(str1)

# %%
str1 = "hello"
print(str1[:-1])
print(str1[::-1])
print(reversed(str1))
li = [3,45,78,95]
print(li.reverse())
print(li)
print(list(reversed(li)))
print(li)

# %%
def test():
    a=96
    print(a)
a =+ 2
print(a)
test()

# %%
def func(x):
    x += [15]
    print("Inside  the function list: ", x)
res = [11, 12, 13, 14]
func(res)
print("Outside the function list: ", res)

# %%
f=open("story.txt", "a+")
story = "Education Hub\nLearning is the key of success."
f.write(story)
print(f.read())
str= " "
s=0
ts=0
while str:
    str=f.readline()
    ts=ts+len(str)
print(ts)
f.close()

# %%
with open("story.txt") as f:
    str= " "
    s=0
    ts=0
    while str:
        str=f.readline()
        ts=ts+len(str)
    print(ts)

# %%
with open("story.txt") as f:
    s = f.read()
    z = s.split()
    print(z)
    lines = 0
    for i in z:
        if i != "Learning" :
            lines+=1
    print(lines)

# %% [markdown]
# Default separator is 'space' and default end is 'endline'

# %%
a = 5
a = 10
a = 'hello'
print('My', 'name', 'is', 'Anthony', 'Gonzalvis', sep = '-', end = '!')

# %%
for i in range(5):
    print(i)
else:
    print('Loop runs successfully.')

# %%
for i in range(5):
    print(i)
    if i == 3:
        break
else:
    print('Loop runs successfully.')

# %%
# Out:
#   File "<ipython-input-6-20c0579e393c>", line 1
#     12 = True
#     ^
# SyntaxError: cannot assign to literal

# %%
str1 = 'hello'
str2 = 'nah he tweeking'
print(str1 , str2)
print(str1 + str2b)
# Out:
# hello nah he tweeking
# hellonah he tweeking!

# %%
a = 2
if a == 1:
    print('One')
if a == 2:
    print('Two')
if a == 3:
    print('Three')
else:
    print('Howaaaat!') #if-else runs in a group
# Out:
# Two
# Howaaaat!

# %%
#Printing every number except 4
i = 1
while (i < 11):
    if i == 4:
        i += 1
        continue
    print(i, end = ' ')
    i += 1
# Out:
# 1 2 3 5 6 7 8 9 10

# %%
a = 'Harsh'
b = input()
if a == b:
    print('True')
if a is b:
    print('True again')
# Out:
# Harsh
# True

# %%
float('12')
# Double step conversion is not possible, here str -> int -> float
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-4621c271aa92> in <module>
# ----> 1 float('12')
#
# TypeError: 'str' object is not callable

# %%
time = int(input("Enter time is seconds: "))
m = time // 60
s = time % 60
print(f'{m} minutes {s} seconds')
# Out:
# Enter time is seconds: 422
# 7 minutes 2 seconds

# %%
a = "Hello World!"
a[::-1]
# Out:
# '!dlroW olleH'

# %%
a = "helllo"
a.capitalize()
a.find("l",0,)
# Out:
# 2

# %%
a = "My age is {} years."
age = 36
print(a.format(age))
# Out:
# My age is 36 years.

# %%
print("This is carriage\r return.")
print("111 111\r000")
# Out:
#  return.
# 000

# %%
# !python --version
# Out:
# Python 3.8.8

# %%
import random
li = []
for i in range(1000):
    li.append(random.uniform(0,1))
# Out:
# [0.7028592682705275, 0.6907986826418959, 0.4089726999249359, 0.42026525811613114, 0.5557292646612215, 0.10959699436608827, 0.9708096760767779, 0.6473444424029633, 0.135007039213061, 0.705410049719767, 0.5519306209755095, 0.3807905352060137, 0.8973712640433096, 0.24856159687567958, 0.5133810329669981, 0.3795349540559618, 0.8292143227398301, 0.2155497569017456, 0.33560647016256095, 0.5105891586412261, 0.2272399662461877, 0.31166993648783703, 0.9266568159853869, 0.8416278784166743, 0.6547339587209935, 0.7717850357856716, 0.7781962525225519, 0.21117868029267461, 0.9641702526577963, 0.8866121152211434, 0.4637933484548131, 0.016907491211951564, 0.09013857900285338, 0.1980402429124034, 0.20583788752883725, 0.7594300476741267, 0.28428934984264864, 0.527882987793106, 0.9981283368137571, 0.8157655792625155, 0.7487085768707417, 0.8282686784197844, 0.6474183624737091, 0.005653938120640967, 0.803676735693268, 0.12002932102971764, 0.08458061471236089, 0.0011007036295219708, 0.7386204229151522, 0.7
# ...

# %%
exmp2 = 'Example2.txt'

# %%
with open(exmp2, 'w') as writefile:
    writefile.write("This is line A\n")
    writefile.write("This is line B\n")

# %%
# read file

with open(exmp2, 'r') as file:
    print(file.read())
# Out:
# This is line A
# This is line B
# This is line C
# This is line C
# This is line D
# This is line E

# %%
Lines = ["This is line A\n", "This is line B\n", "This is line C\n"]
Lines
# Out:
# ['This is line A\n', 'This is line B\n', 'This is line C\n']

# %%
with open(exmp2, 'w+') as file:
    for line in Lines:
        file.write(line)
    print(file.read())

# %%
with open('Example2.txt', 'a') as file:
    file.write("This is line C\n")
    file.write("This is line D\n")
    file.write("This is line E\n")

# %%
with open('Example2.txt', 'a+') as testwritefile:
    testwritefile.write("This is line E\n")
    print(testwritefile.read())

# %%
with open('Example2.txt', 'a+') as testwritefile:
    print("Initial Location: {}".format(testwritefile.tell()))
    
    data = testwritefile.read()
    if (not data):  #empty strings return false in python
            print('Read nothing') 
    else: 
            print(testwritefile.read())
            
    testwritefile.seek(0,0) # move 0 bytes from beginning.
    
    print("\nNew Location : {}".format(testwritefile.tell()))
    data = testwritefile.read()
    if (not data): 
            print('Read nothing') 
    else: 
            print(data)
    
    print("Location after read: {}".format(testwritefile.tell()) )
# Out:
# Initial Location: 96
# Read nothing
#
# New Location : 0
# This is line A
# This is line B
# This is line C
# This is line C
# This is line D
# This is line E
#
# Location after read: 96

# %%
with open('Example2.txt', 'r+') as testwritefile:
    data = testwritefile.readlines()
    testwritefile.seek(0,0) #write at beginning of file
   
    testwritefile.write("Line 1" + "\n")
    testwritefile.write("Line 2" + "\n")
    testwritefile.write("Line 3" + "\n")
    testwritefile.write("finished\n")
    #Uncomment the line below
    testwritefile.truncate()
    testwritefile.seek(0,0)
    print(testwritefile.read())
# Out:
# Line 1
# Line 2
# Line 3
# finished

# %%
#Copying
with open(exmp2, 'r') as readfile:
    with open('Example3.txt', 'w') as writefile:
        for line in readfile.read():
            writefile.write(line)

# %%
with open('Example3.txt', 'r') as file:
    print(file.read())
# Out:
# Line 1
# Line 2
# Line 3
# finished
